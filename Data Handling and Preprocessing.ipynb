# %%
import pandas as pd
df=pd.read_csv('dataset/Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total    HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison    318  45.0      49
# 1      2                Ivysaur    Grass  Poison    405  60.0      62
# 2      3               Venusaur    Grass  Poison    525  80.0      82
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   NaN     100
# 4      4             Charmander     Fire     NaN    309  39.0      52
# ..   ...                    ...      ...     ...    ...   ...     ...
# 795  719                Diancie     Rock   Fairy    600  50.0     100
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50.0     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80.0     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80.0     160
# 799  721              Volcanion     Fire   Water    600  80.0     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65   45.0           1      False
# ...

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              1
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           1
# Generation      0
# Legendary       0
# dtype: int64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total    HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison    318  45.0      49
# 1      2                Ivysaur    Grass  Poison    405  60.0      62
# 2      3               Venusaur    Grass  Poison    525  80.0      82
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   NaN     100
# 4      4             Charmander     Fire     NaN    309  39.0      52
# ..   ...                    ...      ...     ...    ...   ...     ...
# 795  719                Diancie     Rock   Fairy    600  50.0     100
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50.0     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80.0     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80.0     160
# 799  721              Volcanion     Fire   Water    600  80.0     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65   45.0           1      False
# ...

# %%
df.head(30)
# Out:
#      #                       Name  Type 1  Type 2  Total    HP  Attack  \
# 0    1                  Bulbasaur   Grass  Poison    318  45.0      49
# 1    2                    Ivysaur   Grass  Poison    405  60.0      62
# 2    3                   Venusaur   Grass  Poison    525  80.0      82
# 3    3      VenusaurMega Venusaur   Grass  Poison    625   NaN     100
# 4    4                 Charmander    Fire     NaN    309  39.0      52
# 5    5                 Charmeleon    Fire     NaN    405  58.0      64
# 6    6                  Charizard    Fire  Flying    534  78.0      84
# 7    6  CharizardMega Charizard X    Fire  Dragon    634  78.0     130
# 8    6  CharizardMega Charizard Y    Fire  Flying    634  78.0     104
# 9    7                   Squirtle   Water     NaN    314  44.0      48
# 10   8                  Wartortle   Water     NaN    405  59.0      63
# 11   9                  Blastoise   Water     NaN    530  79.0      83
# ...

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total     HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40.0      30       35
# 791  715              Noivern   Flying  Dragon    535   85.0      70       80
# 792  716              Xerneas    Fairy     NaN    680  126.0     131       95
# 793  717              Yveltal     Dark  Flying    680  126.0     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108.0     100      121
# 795  719              Diancie     Rock   Fairy    600   50.0     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50.0     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80.0     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80.0     160       60
# 799  721            Volcanion     Fire   Water    600   80.0     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40   55.0           6      False
# ...

# %%
#fill null values
df.fillna(0).head(30)
# Out:
#      #                       Name  Type 1  Type 2  Total    HP  Attack  \
# 0    1                  Bulbasaur   Grass  Poison    318  45.0      49
# 1    2                    Ivysaur   Grass  Poison    405  60.0      62
# 2    3                   Venusaur   Grass  Poison    525  80.0      82
# 3    3      VenusaurMega Venusaur   Grass  Poison    625   0.0     100
# 4    4                 Charmander    Fire       0    309  39.0      52
# 5    5                 Charmeleon    Fire       0    405  58.0      64
# 6    6                  Charizard    Fire  Flying    534  78.0      84
# 7    6  CharizardMega Charizard X    Fire  Dragon    634  78.0     130
# 8    6  CharizardMega Charizard Y    Fire  Flying    634  78.0     104
# 9    7                   Squirtle   Water       0    314  44.0      48
# 10   8                  Wartortle   Water       0    405  59.0      63
# 11   9                  Blastoise   Water       0    530  79.0      83
# ...

# %%
df['Type 2'].fillna('Flying')
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4      Flying
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
df['Type 2'].value_counts()

#df['Type 2'].unique
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
df['Type 2'].nunique()
# Out:
# 18

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
#missing value 
# constant 0 , flying
# statiscal information  -> mode
# method 
# condtional customize

df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
round(df['HP'].mean(),2)
# Out:
# 69.25

# %%
df['HP'].max()
# Out:
# 255.0

# %%
df['HP'].min()
# Out:
# 1.0

# %%
df['HP'].std()
# Out:
# 25.547830219946505

# %%
df['HP'].isnull().sum()
# Out:
# 1

# %%
df['HP'].fillna(df['Generation'].min())
# Out:
# 0      45.0
# 1      60.0
# 2      80.0
# 3       1.0
# 4      39.0
#        ...
# 795    50.0
# 796    50.0
# 797    80.0
# 798    80.0
# 799    80.0
# Name: HP, Length: 800, dtype: float64

# %%
df['Type 2'].fillna(df['Type 2'].mode()[0]) #mode
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4      Flying
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
df['Type 2'].mode()[0]
# Out:
# 'Flying'

# %%
df["HP"].fillna(method='pad')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10932\3729209011.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["HP"].fillna(method='pad')
# 0      45.0
# 1      60.0
# 2      80.0
# 3      80.0
# 4      39.0
#        ...
# 795    50.0
# 796    50.0
# 797    80.0
# 798    80.0
# 799    80.0
# Name: HP, Length: 800, dtype: float64

# %%
df["HP"].fillna(method='bfill')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10932\879909116.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["HP"].fillna(method='bfill')
# 0      45.0
# 1      60.0
# 2      80.0
# 3      39.0
# 4      39.0
#        ...
# 795    50.0
# 796    50.0
# 797    80.0
# 798    80.0
# 799    80.0
# Name: HP, Length: 800, dtype: float64

# %%
df['HP'].interpolate()
# Out:
# 0      45.0
# 1      60.0
# 2      80.0
# 3      59.5
# 4      39.0
#        ...
# 795    50.0
# 796    50.0
# 797    80.0
# 798    80.0
# 799    80.0
# Name: HP, Length: 800, dtype: float64

# %%
df['HP']
# Out:
# 0      45.0
# 1      60.0
# 2      80.0
# 3       NaN
# 4      39.0
#        ...
# 795    50.0
# 796    50.0
# 797    80.0
# 798    80.0
# 799    80.0
# Name: HP, Length: 800, dtype: float64

# %%
df.iloc[3,5]=10000 #index of location

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total       HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison    318     45.0      49
# 1      2                Ivysaur    Grass  Poison    405     60.0      62
# 2      3               Venusaur    Grass  Poison    525     80.0      82
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  10000.0     100
# 4      4             Charmander     Fire     NaN    309     39.0      52
# ..   ...                    ...      ...     ...    ...      ...     ...
# 795  719                Diancie     Rock   Fairy    600     50.0     100
# 796  719    DiancieMega Diancie     Rock   Fairy    700     50.0     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600     80.0     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680     80.0     160
# 799  721              Volcanion     Fire   Water    600     80.0     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=10, random_state=0)
imp.fit([[1, 2], [3, 6], [4, 8], [np.nan, 3], [7, np.nan]])
X_test = [[np.nan, 2], [6, np.nan], [np.nan, 6]]
# the model learns that the second feature is double the first
print(np.round(imp.transform(X_test)))
# Out:
# [[ 1.  2.]
#  [ 6. 12.]
#  [ 3.  6.]]

# %%
#Sklearn imptutation 
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           1
# Generation      0
# Legendary       0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(df['Speed'].values.reshape(-1,1)) #imp_mean.fit(df[['HP','Speed']])
print(imp_mean.transform(df['Speed'].values.reshape(-1,1)))
# Out:
# [[ 45.        ]
#  [ 60.        ]
#  [ 80.        ]
#  [ 80.        ]
#  [ 65.        ]
#  [ 80.        ]
#  [100.        ]
#  [ 68.23779725]
#  [100.        ]
#  [ 43.        ]
#  [ 58.        ]
#  [ 78.        ]
#  [ 78.        ]
#  [ 45.        ]
#  [ 30.        ]
#  [ 70.        ]
#  [ 50.        ]
#  [ 35.        ]
#  [ 75.        ]
#  [145.        ]
#  [ 56.        ]
#  [ 71.        ]
#  [101.        ]
#  [121.        ]
#  [ 72.        ]
#  [ 97.        ]
#  [ 70.        ]
#  [100.        ]
#  [ 55.        ]
#  [ 80.        ]
#  [ 90.        ]
#  [110.        ]
#  [ 40.        ]
#  [ 65.        ]
#  [ 41.        ]
#  [ 56.        ]
#  [ 76.        ]
#  [ 50.        ]
#  [ 65.        ]
#  [ 85.        ]
#  [ 35.        ]
#  [ 60.        ]
#  [ 65.        ]
#  [100.        ]
#  [ 20.        ]
#  [ 45.        ]
#  [ 55.        ]
#  [ 90.        ]
#  [ 30.        ]
#  [ 40.        ]
#  [ 50.        ]
#  [ 25.        ]
#  [ 30.        ]
#  [ 45.        ]
#  [ 90.        ]
# ...

# %%
type(df['Speed'])
# Out:
# pandas.core.series.Series

# %%
df['Speed'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       45.0
# 1       60.0
# 2       80.0
# 3       80.0
# 4       65.0
#        ...
# 795     50.0
# 796    110.0
# 797     70.0
# 798     80.0
# 799     70.0
# Name: Speed, Length: 800, dtype: float64>

# %%
df['Speed'].values.reshape(-1,1) #row vector
# Out:
# array([[ 45.],
#        [ 60.],
#        [ 80.],
#        [ 80.],
#        [ 65.],
#        [ 80.],
#        [100.],
#        [ nan],
#        [100.],
#        [ 43.],
#        [ 58.],
#        [ 78.],
#        [ 78.],
#        [ 45.],
#        [ 30.],
#        [ 70.],
#        [ 50.],
#        [ 35.],
#        [ 75.],
#        [145.],
#        [ 56.],
#        [ 71.],
#        [101.],
#        [121.],
#        [ 72.],
#        [ 97.],
#        [ 70.],
#        [100.],
#        [ 55.],
#        [ 80.],
#        [ 90.],
#        [110.],
#        [ 40.],
#        [ 65.],
#        [ 41.],
#        [ 56.],
#        [ 76.],
#        [ 50.],
#        [ 65.],
#        [ 85.],
#        [ 35.],
#        [ 60.],
#        [ 65.],
#        [100.],
#        [ 20.],
#        [ 45.],
#        [ 55.],
#        [ 90.],
#        [ 30.],
#        [ 40.],
#        [ 50.],
#        [ 25.],
#        [ 30.],
#        [ 45.],
#        [ 90.],
#        [ 95.],
#        [120.],
#        [ 90.],
# ...

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
type2 = poke['Type 2'].values.reshape(-1, 1)# poke[['Type 1','Type 2']]
imp_mean.fit(type2)
df['Type 2']=imp_mean.transform(type2)

#imp_mean.fit_transform(type2)

# %%
df.to_csv('dd.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total       HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison    318     45.0      49
# 1      2                Ivysaur    Grass  Poison    405     60.0      62
# 2      3               Venusaur    Grass  Poison    525     80.0      82
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  10000.0     100
# 4      4             Charmander     Fire     NaN    309     39.0      52
# ..   ...                    ...      ...     ...    ...      ...     ...
# 795  719                Diancie     Rock   Fairy    600     50.0     100
# 796  719    DiancieMega Diancie     Rock   Fairy    700     50.0     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600     80.0     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680     80.0     160
# 799  721              Volcanion     Fire   Water    600     80.0     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[['HP','Speed']].corr()
# Out:
#              HP     Speed
# HP     1.000000  0.027024
# Speed  0.027024  1.000000
